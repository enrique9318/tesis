# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
from sklearn.metrics import confusion_matrix
import time
from datetime import timedelta
import math

# %%
# Convolutional Layer 1.
filter_size1 = 5          # Convolution filters are 5 x 5 pixels.
num_filters1 = 16         # There are 16 of these filters.

# Convolutional Layer 2.
filter_size2 = 5          # Convolution filters are 5 x 5 pixels.
num_filters2 = 36         # There are 36 of these filters.

# Fully-connected layer.
fc_size = 128

# %%
from tensorflow.examples.tutorials.mnist import input_data
data = input_data.read_data_sets('data/MNIST/', one_hot=True)
# Out:
# Successfully downloaded train-images-idx3-ubyte.gz 9912422 bytes.
# Extracting data/MNIST/train-images-idx3-ubyte.gz
# Successfully downloaded train-labels-idx1-ubyte.gz 28881 bytes.
# Extracting data/MNIST/train-labels-idx1-ubyte.gz
# Successfully downloaded t10k-images-idx3-ubyte.gz 1648877 bytes.
# Extracting data/MNIST/t10k-images-idx3-ubyte.gz
# Successfully downloaded t10k-labels-idx1-ubyte.gz 4542 bytes.
# Extracting data/MNIST/t10k-labels-idx1-ubyte.gz

# %%
print("Size of:")
print("- Training-set:\t\t{}".format(len(data.train.labels)))
print("- Test-set:\t\t{}".format(len(data.test.labels)))
print("- Validation-set:\t{}".format(len(data.validation.labels)))
# Out:
# Size of:
# - Training-set:		55000
# - Test-set:		10000
# - Validation-set:	5000

# %%
data.test.cls = np.argmax(data.test.labels, axis=1)

# %%
# We know that MNIST images are 28 pixels in each dimension.
img_size = 28

# Images are stored in one-dimensional arrays of this length.
img_size_flat = img_size * img_size

# Tuple with height and width of images used to reshape arrays.
img_shape = (img_size, img_size)

# Number of colour channels for the images: 1 channel for gray-scale.
num_channels = 1

# Number of classes, one class for each of 10 digits.
num_classes = 10

# %%
def plot_images(images, cls_true, cls_pred=None):
    assert len(images) == len(cls_true) == 9
    
    # Create figure with 3x3 sub-plots.
    fig, axes = plt.subplots(3, 3)
    fig.subplots_adjust(hspace=0.3, wspace=0.3)

    for i, ax in enumerate(axes.flat):
        # Plot image.
        ax.imshow(images[i].reshape(img_shape), cmap='binary')

        # Show true and predicted classes.
        if cls_pred is None:
            xlabel = "True: {0}".format(cls_true[i])
        else:
            xlabel = "True: {0}, Pred: {1}".format(cls_true[i], cls_pred[i])

        # Show the classes as the label on the x-axis.
        ax.set_xlabel(xlabel)
        
        # Remove ticks from the plot.
        ax.set_xticks([])
        ax.set_yticks([])
    
    # Ensure the plot is shown correctly with multiple plots
    # in a single Notebook cell.
    plt.show()

# %%
# Get the first images from the test-set.
images = data.test.images[0:9]

# Get the true classes for those images.
cls_true = data.test.cls[0:9]

# Plot the images and labels using our helper-function above.
plot_images(images=images, cls_true=cls_true)

# %%
def new_weights(shape):
    return tf.Variable(tf.truncated_normal(shape, stddev=0.05))
def new_biases(length):
    return tf.Variable(tf.constant(0.05, shape=[length]))

# %%
def new_conv_layer(input,              # The previous layer.
                   num_input_channels, # Num. channels in prev. layer.
                   filter_size,        # Width and height of each filter.
                   num_filters,        # Number of filters.
                   use_pooling=True):  # Use 2x2 max-pooling.

    # Shape of the filter-weights for the convolution.
    # This format is determined by the TensorFlow API.
    shape = [filter_size, filter_size, num_input_channels, num_filters]

    # Create new weights aka. filters with the given shape.
    weights = new_weights(shape=shape)

    # Create new biases, one for each filter.
    biases = new_biases(length=num_filters)

    # Create the TensorFlow operation for convolution.
    # Note the strides are set to 1 in all dimensions.
    # The first and last stride must always be 1,
    # because the first is for the image-number and
    # the last is for the input-channel.
    # But e.g. strides=[1, 2, 2, 1] would mean that the filter
    # is moved 2 pixels across the x- and y-axis of the image.
    # The padding is set to 'SAME' which means the input image
    # is padded with zeroes so the size of the output is the same.
    layer = tf.nn.conv2d(input=input,
                         filter=weights,
                         strides=[1, 1, 1, 1],
                         padding='SAME')

    # Add the biases to the results of the convolution.
    # A bias-value is added to each filter-channel.
    layer += biases

    # Use pooling to down-sample the image resolution?
    if use_pooling:
        # This is 2x2 max-pooling, which means that we
        # consider 2x2 windows and select the largest value
        # in each window. Then we move 2 pixels to the next window.
        layer = tf.nn.max_pool(value=layer,
                               ksize=[1, 2, 2, 1],
                               strides=[1, 2, 2, 1],
                               padding='SAME')

    # Rectified Linear Unit (ReLU).
    # It calculates max(x, 0) for each input pixel x.
    # This adds some non-linearity to the formula and allows us
    # to learn more complicated functions.
    layer = tf.nn.relu(layer)

    # Note that ReLU is normally executed before the pooling,
    # but since relu(max_pool(x)) == max_pool(relu(x)) we can
    # save 75% of the relu-operations by max-pooling first.

    # We return both the resulting layer and the filter-weights
    # because we will plot the weights later.
    return layer, weights

# %%
def flatten_layer(layer):
    # Get the shape of the input layer.
    layer_shape = layer.get_shape()

    # The shape of the input layer is assumed to be:
    # layer_shape == [num_images, img_height, img_width, num_channels]

    # The number of features is: img_height * img_width * num_channels
    # We can use a function from TensorFlow to calculate this.
    num_features = layer_shape[1:4].num_elements()
    
    # Reshape the layer to [num_images, num_features].
    # Note that we just set the size of the second dimension
    # to num_features and the size of the first dimension to -1
    # which means the size in that dimension is calculated
    # so the total size of the tensor is unchanged from the reshaping.
    layer_flat = tf.reshape(layer, [-1, num_features])

    # The shape of the flattened layer is now:
    # [num_images, img_height * img_width * num_channels]

    # Return both the flattened layer and the number of features.
    return layer_flat, num_features

# %%
def new_fc_layer(input,          # The previous layer.
                 num_inputs,     # Num. inputs from prev. layer.
                 num_outputs,    # Num. outputs.
                 use_relu=True): # Use Rectified Linear Unit (ReLU)?

    # Create new weights and biases.
    weights = new_weights(shape=[num_inputs, num_outputs])
    biases = new_biases(length=num_outputs)

    # Calculate the layer as the matrix multiplication of
    # the input and weights, and then add the bias-values.
    layer = tf.matmul(input, weights) + biases

    # Use ReLU?
    if use_relu:
        layer = tf.nn.relu(layer)

    return layer

# %%
x = tf.placeholder(tf.float32, shape=[None, img_size_flat], name='x')
x_image = tf.reshape(x, [-1, img_size, img_size, num_channels])
y_true = tf.placeholder(tf.float32, shape=[None, num_classes], name='y_true')
y_true_cls = tf.argmax(y_true, dimension=1)

# %%
layer_conv1, weights_conv1 = \
    new_conv_layer(input=x_image,
                   num_input_channels=num_channels,
                   filter_size=filter_size1,
                   num_filters=num_filters1,
                   use_pooling=True)
layer_conv1
# Out:
# <tf.Tensor 'Relu:0' shape=(?, 14, 14, 16) dtype=float32>

# %%
layer_conv2, weights_conv2 = \
    new_conv_layer(input=layer_conv1,
                   num_input_channels=num_filters1,
                   filter_size=filter_size2,
                   num_filters=num_filters2,
                   use_pooling=True)

layer_conv2
# Out:
# <tf.Tensor 'Relu_1:0' shape=(?, 7, 7, 36) dtype=float32>

# %%
layer_flat, num_features = flatten_layer(layer_conv2)

# %%
layer_fc1 = new_fc_layer(input=layer_flat,
                         num_inputs=num_features,
                         num_outputs=fc_size,
                         use_relu=True)

# %%
layer_fc2 = new_fc_layer(input=layer_fc1,
                         num_inputs=fc_size,
                         num_outputs=num_classes,
                         use_relu=False)

# %%
y_pred = tf.nn.softmax(layer_fc2)

# %%
y_pred_cls = tf.argmax(y_pred, dimension=1)

# %%
cross_entropy = tf.nn.softmax_cross_entropy_with_logits(logits=layer_fc2,
                                                        labels=y_true)

# %%
cost = tf.reduce_mean(cross_entropy)

# %%
optimizer = tf.train.AdamOptimizer(learning_rate=1e-4).minimize(cost)

# %%
correct_prediction = tf.equal(y_pred_cls, y_true_cls)

# %%
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

# %%
session = tf.Session(config=tf.ConfigProto(log_device_placement=True))

# %%
session.run(tf.global_variables_initializer())

# %%
train_batch_size = 64

# %%
# Counter for total number of iterations performed so far.
total_iterations = 0

with tf.device('/gpu:0'):
    def optimize(num_iterations):
        # Ensure we update the global variable rather than a local copy.
        global total_iterations

        # Start-time used for printing time-usage below.
        start_time = time.time()

        for i in range(total_iterations,
                       total_iterations + num_iterations):

            # Get a batch of training examples.
            # x_batch now holds a batch of images and
            # y_true_batch are the true labels for those images.
            x_batch, y_true_batch = data.train.next_batch(train_batch_size)

            # Put the batch into a dict with the proper names
            # for placeholder variables in the TensorFlow graph.
            feed_dict_train = {x: x_batch,
                               y_true: y_true_batch}

            # Run the optimizer using this batch of training data.
            # TensorFlow assigns the variables in feed_dict_train
            # to the placeholder variables and then runs the optimizer.
            session.run(optimizer, feed_dict=feed_dict_train)

            # Print status every 100 iterations.
            if i % 100 == 0:
                # Calculate the accuracy on the training-set.
                acc = session.run(accuracy, feed_dict=feed_dict_train)

                # Message for printing.
                msg = "Optimization Iteration: {0:>6}, Training Accuracy: {1:>6.1%}"

                # Print it.
                print(msg.format(i + 1, acc))

        # Update the total number of iterations performed.
        total_iterations += num_iterations

        # Ending time.
        end_time = time.time()

        # Difference between start and end-times.
        time_dif = end_time - start_time

        # Print the time-usage.
        print("Time usage: " + str(timedelta(seconds=int(round(time_dif)))))

# %%
def plot_example_errors(cls_pred, correct):
    # This function is called from print_test_accuracy() below.

    # cls_pred is an array of the predicted class-number for
    # all images in the test-set.

    # correct is a boolean array whether the predicted class
    # is equal to the true class for each image in the test-set.

    # Negate the boolean array.
    incorrect = (correct == False)
    
    # Get the images from the test-set that have been
    # incorrectly classified.
    images = data.test.images[incorrect]
    
    # Get the predicted classes for those images.
    cls_pred = cls_pred[incorrect]

    # Get the true classes for those images.
    cls_true = data.test.cls[incorrect]
    
    # Plot the first 9 images.
    plot_images(images=images[0:9],
                cls_true=cls_true[0:9],
                cls_pred=cls_pred[0:9])

# %%
def plot_confusion_matrix(cls_pred):
    # This is called from print_test_accuracy() below.

    # cls_pred is an array of the predicted class-number for
    # all images in the test-set.

    # Get the true classifications for the test-set.
    cls_true = data.test.cls
    
    # Get the confusion matrix using sklearn.
    cm = confusion_matrix(y_true=cls_true,
                          y_pred=cls_pred)

    # Print the confusion matrix as text.
    print(cm)

    # Plot the confusion matrix as an image.
    plt.matshow(cm)

    # Make various adjustments to the plot.
    plt.colorbar()
    tick_marks = np.arange(num_classes)
    plt.xticks(tick_marks, range(num_classes))
    plt.yticks(tick_marks, range(num_classes))
    plt.xlabel('Predicted')
    plt.ylabel('True')

    # Ensure the plot is shown correctly with multiple plots
    # in a single Notebook cell.
    plt.show()

# %%
# Split the test-set into smaller batches of this size.
test_batch_size = 256

def print_test_accuracy(show_example_errors=False,
                        show_confusion_matrix=False):

    # Number of images in the test-set.
    num_test = len(data.test.images)

    # Allocate an array for the predicted classes which
    # will be calculated in batches and filled into this array.
    cls_pred = np.zeros(shape=num_test, dtype=np.int)

    # Now calculate the predicted classes for the batches.
    # We will just iterate through all the batches.
    # There might be a more clever and Pythonic way of doing this.

    # The starting index for the next batch is denoted i.
    i = 0

    while i < num_test:
        # The ending index for the next batch is denoted j.
        j = min(i + test_batch_size, num_test)

        # Get the images from the test-set between index i and j.
        images = data.test.images[i:j, :]

        # Get the associated labels.
        labels = data.test.labels[i:j, :]

        # Create a feed-dict with these images and labels.
        feed_dict = {x: images,
                     y_true: labels}

        # Calculate the predicted class using TensorFlow.
        cls_pred[i:j] = session.run(y_pred_cls, feed_dict=feed_dict)

        # Set the start-index for the next batch to the
        # end-index of the current batch.
        i = j

    # Convenience variable for the true class-numbers of the test-set.
    cls_true = data.test.cls

    # Create a boolean array whether each image is correctly classified.
    correct = (cls_true == cls_pred)

    # Calculate the number of correctly classified images.
    # When summing a boolean array, False means 0 and True means 1.
    correct_sum = correct.sum()

    # Classification accuracy is the number of correctly classified
    # images divided by the total number of images in the test-set.
    acc = float(correct_sum) / num_test

    # Print the accuracy.
    msg = "Accuracy on Test-Set: {0:.1%} ({1} / {2})"
    print(msg.format(acc, correct_sum, num_test))

    # Plot some examples of mis-classifications, if desired.
    if show_example_errors:
        print("Example errors:")
        plot_example_errors(cls_pred=cls_pred, correct=correct)

    # Plot the confusion matrix, if desired.
    if show_confusion_matrix:
        print("Confusion Matrix:")
        plot_confusion_matrix(cls_pred=cls_pred)

# %%
print_test_accuracy()
# Out:
# Accuracy on Test-Set: 13.8% (1383 / 10000)

# %%
optimize(num_iterations=100000)
# Out:
# Optimization Iteration:   1001, Training Accuracy:  95.3%
# Optimization Iteration:   1101, Training Accuracy:  89.1%
# Optimization Iteration:   1201, Training Accuracy:  93.8%
# Optimization Iteration:   1301, Training Accuracy:  96.9%
# Optimization Iteration:   1401, Training Accuracy:  92.2%
# Optimization Iteration:   1501, Training Accuracy:  98.4%
# Optimization Iteration:   1601, Training Accuracy:  96.9%
# Optimization Iteration:   1701, Training Accuracy:  93.8%
# Optimization Iteration:   1801, Training Accuracy:  96.9%
# Optimization Iteration:   1901, Training Accuracy:  92.2%
# Optimization Iteration:   2001, Training Accuracy: 100.0%
# Optimization Iteration:   2101, Training Accuracy:  96.9%
# Optimization Iteration:   2201, Training Accuracy: 100.0%
# Optimization Iteration:   2301, Training Accuracy:  93.8%
# Optimization Iteration:   2401, Training Accuracy:  98.4%
# Optimization Iteration:   2501, Training Accuracy:  98.4%
# Optimization Iteration:   2601, Training Accuracy:  96.9%
# Optimization Iteration:   2701, Training Accuracy:  95.3%
# Optimization Iteration:   2801, Training Accuracy:  96.9%
# Optimization Iteration:   2901, Training Accuracy:  95.3%
# Optimization Iteration:   3001, Training Accuracy:  98.4%
# Optimization Iteration:   3101, Training Accuracy: 100.0%
# Optimization Iteration:   3201, Training Accuracy: 100.0%
# Optimization Iteration:   3301, Training Accuracy:  98.4%
# Optimization Iteration:   3401, Training Accuracy: 100.0%
# Optimization Iteration:   3501, Training Accuracy:  98.4%
# Optimization Iteration:   3601, Training Accuracy: 100.0%
# Optimization Iteration:   3701, Training Accuracy:  95.3%
# Optimization Iteration:   3801, Training Accuracy:  96.9%
# Optimization Iteration:   3901, Training Accuracy:  95.3%
# Optimization Iteration:   4001, Training Accuracy: 100.0%
# Optimization Iteration:   4101, Training Accuracy:  93.8%
# Optimization Iteration:   4201, Training Accuracy:  98.4%
# Optimization Iteration:   4301, Training Accuracy:  98.4%
# Optimization Iteration:   4401, Training Accuracy: 100.0%
# Optimization Iteration:   4501, Training Accuracy: 100.0%
# Optimization Iteration:   4601, Training Accuracy:  98.4%
# Optimization Iteration:   4701, Training Accuracy:  98.4%
# Optimization Iteration:   4801, Training Accuracy:  96.9%
# Optimization Iteration:   4901, Training Accuracy:  98.4%
# Optimization Iteration:   5001, Training Accuracy: 100.0%
# Optimization Iteration:   5101, Training Accuracy:  98.4%
# Optimization Iteration:   5201, Training Accuracy:  98.4%
# Optimization Iteration:   5301, Training Accuracy:  96.9%
# Optimization Iteration:   5401, Training Accuracy: 100.0%
# Optimization Iteration:   5501, Training Accuracy:  98.4%
# Optimization Iteration:   5601, Training Accuracy:  98.4%
# Optimization Iteration:   5701, Training Accuracy:  96.9%
# Optimization Iteration:   5801, Training Accuracy:  95.3%
# Optimization Iteration:   5901, Training Accuracy: 100.0%
# Optimization Iteration:   6001, Training Accuracy:  98.4%
# Optimization Iteration:   6101, Training Accuracy:  96.9%
# Optimization Iteration:   6201, Training Accuracy:  96.9%
# Optimization Iteration:   6301, Training Accuracy: 100.0%
# Optimization Iteration:   6401, Training Accuracy: 100.0%
# Optimization Iteration:   6501, Training Accuracy: 100.0%
# Optimization Iteration:   6601, Training Accuracy: 100.0%
# Optimization Iteration:   6701, Training Accuracy:  96.9%
# Optimization Iteration:   6801, Training Accuracy: 100.0%
# Optimization Iteration:   6901, Training Accuracy:  98.4%
# Optimization Iteration:   7001, Training Accuracy:  98.4%
# Optimization Iteration:   7101, Training Accuracy: 100.0%
# Optimization Iteration:   7201, Training Accuracy:  96.9%
# Optimization Iteration:   7301, Training Accuracy:  96.9%
# Optimization Iteration:   7401, Training Accuracy:  98.4%
# Optimization Iteration:   7501, Training Accuracy:  98.4%
# Optimization Iteration:   7601, Training Accuracy: 100.0%
# Optimization Iteration:   7701, Training Accuracy:  98.4%
# Optimization Iteration:   7801, Training Accuracy:  98.4%
# Optimization Iteration:   7901, Training Accuracy: 100.0%
# Optimization Iteration:   8001, Training Accuracy:  96.9%
# Optimization Iteration:   8101, Training Accuracy:  96.9%
# Optimization Iteration:   8201, Training Accuracy:  98.4%
# Optimization Iteration:   8301, Training Accuracy:  96.9%
# Optimization Iteration:   8401, Training Accuracy: 100.0%
# Optimization Iteration:   8501, Training Accuracy:  96.9%
# Optimization Iteration:   8601, Training Accuracy: 100.0%
# Optimization Iteration:   8701, Training Accuracy:  98.4%
# Optimization Iteration:   8801, Training Accuracy:  96.9%
# Optimization Iteration:   8901, Training Accuracy:  98.4%
# Optimization Iteration:   9001, Training Accuracy:  98.4%
# Optimization Iteration:   9101, Training Accuracy:  98.4%
# Optimization Iteration:   9201, Training Accuracy:  98.4%
# Optimization Iteration:   9301, Training Accuracy:  98.4%
# Optimization Iteration:   9401, Training Accuracy: 100.0%
# Optimization Iteration:   9501, Training Accuracy: 100.0%
# Optimization Iteration:   9601, Training Accuracy: 100.0%
# Optimization Iteration:   9701, Training Accuracy: 100.0%
# Optimization Iteration:   9801, Training Accuracy:  98.4%
# Optimization Iteration:   9901, Training Accuracy:  98.4%
# Optimization Iteration:  10001, Training Accuracy: 100.0%
# Optimization Iteration:  10101, Training Accuracy: 100.0%
# Optimization Iteration:  10201, Training Accuracy:  98.4%
# Optimization Iteration:  10301, Training Accuracy: 100.0%
# Optimization Iteration:  10401, Training Accuracy: 100.0%
# Optimization Iteration:  10501, Training Accuracy:  98.4%
# Optimization Iteration:  10601, Training Accuracy:  96.9%
# Optimization Iteration:  10701, Training Accuracy: 100.0%
# Optimization Iteration:  10801, Training Accuracy: 100.0%
# Optimization Iteration:  10901, Training Accuracy: 100.0%
# Optimization Iteration:  11001, Training Accuracy: 100.0%
# Optimization Iteration:  11101, Training Accuracy:  98.4%
# Optimization Iteration:  11201, Training Accuracy:  98.4%
# Optimization Iteration:  11301, Training Accuracy:  98.4%
# Optimization Iteration:  11401, Training Accuracy: 100.0%
# Optimization Iteration:  11501, Training Accuracy: 100.0%
# Optimization Iteration:  11601, Training Accuracy: 100.0%
# Optimization Iteration:  11701, Training Accuracy:  96.9%
# Optimization Iteration:  11801, Training Accuracy: 100.0%
# Optimization Iteration:  11901, Training Accuracy: 100.0%
# Optimization Iteration:  12001, Training Accuracy:  98.4%
# Optimization Iteration:  12101, Training Accuracy:  96.9%
# Optimization Iteration:  12201, Training Accuracy:  98.4%
# Optimization Iteration:  12301, Training Accuracy:  98.4%
# Optimization Iteration:  12401, Training Accuracy: 100.0%
# Optimization Iteration:  12501, Training Accuracy:  96.9%
# Optimization Iteration:  12601, Training Accuracy:  98.4%
# Optimization Iteration:  12701, Training Accuracy:  98.4%
# Optimization Iteration:  12801, Training Accuracy:  98.4%
# Optimization Iteration:  12901, Training Accuracy: 100.0%
# Optimization Iteration:  13001, Training Accuracy: 100.0%
# Optimization Iteration:  13101, Training Accuracy: 100.0%
# Optimization Iteration:  13201, Training Accuracy:  96.9%
# Optimization Iteration:  13301, Training Accuracy:  96.9%
# Optimization Iteration:  13401, Training Accuracy: 100.0%
# Optimization Iteration:  13501, Training Accuracy:  98.4%
# Optimization Iteration:  13601, Training Accuracy:  98.4%
# Optimization Iteration:  13701, Training Accuracy: 100.0%
# Optimization Iteration:  13801, Training Accuracy: 100.0%
# Optimization Iteration:  13901, Training Accuracy: 100.0%
# Optimization Iteration:  14001, Training Accuracy: 100.0%
# Optimization Iteration:  14101, Training Accuracy:  98.4%
# Optimization Iteration:  14201, Training Accuracy:  98.4%
# Optimization Iteration:  14301, Training Accuracy: 100.0%
# Optimization Iteration:  14401, Training Accuracy:  96.9%
# Optimization Iteration:  14501, Training Accuracy: 100.0%
# Optimization Iteration:  14601, Training Accuracy: 100.0%
# Optimization Iteration:  14701, Training Accuracy: 100.0%
# Optimization Iteration:  14801, Training Accuracy: 100.0%
# Optimization Iteration:  14901, Training Accuracy:  98.4%
# Optimization Iteration:  15001, Training Accuracy: 100.0%
# Optimization Iteration:  15101, Training Accuracy:  98.4%
# Optimization Iteration:  15201, Training Accuracy: 100.0%
# Optimization Iteration:  15301, Training Accuracy: 100.0%
# Optimization Iteration:  15401, Training Accuracy: 100.0%
# Optimization Iteration:  15501, Training Accuracy: 100.0%
# Optimization Iteration:  15601, Training Accuracy: 100.0%
# Optimization Iteration:  15701, Training Accuracy:  98.4%
# Optimization Iteration:  15801, Training Accuracy:  98.4%
# Optimization Iteration:  15901, Training Accuracy: 100.0%
# Optimization Iteration:  16001, Training Accuracy:  98.4%
# Optimization Iteration:  16101, Training Accuracy:  96.9%
# Optimization Iteration:  16201, Training Accuracy: 100.0%
# Optimization Iteration:  16301, Training Accuracy: 100.0%
# Optimization Iteration:  16401, Training Accuracy: 100.0%
# Optimization Iteration:  16501, Training Accuracy: 100.0%
# Optimization Iteration:  16601, Training Accuracy: 100.0%
# Optimization Iteration:  16701, Training Accuracy: 100.0%
# Optimization Iteration:  16801, Training Accuracy: 100.0%
# Optimization Iteration:  16901, Training Accuracy: 100.0%
# Optimization Iteration:  17001, Training Accuracy: 100.0%
# Optimization Iteration:  17101, Training Accuracy: 100.0%
# Optimization Iteration:  17201, Training Accuracy:  98.4%
# Optimization Iteration:  17301, Training Accuracy: 100.0%
# Optimization Iteration:  17401, Training Accuracy: 100.0%
# Optimization Iteration:  17501, Training Accuracy: 100.0%
# Optimization Iteration:  17601, Training Accuracy: 100.0%
# Optimization Iteration:  17701, Training Accuracy: 100.0%
# Optimization Iteration:  17801, Training Accuracy: 100.0%
# Optimization Iteration:  17901, Training Accuracy:  98.4%
# Optimization Iteration:  18001, Training Accuracy: 100.0%
# Optimization Iteration:  18101, Training Accuracy:  98.4%
# Optimization Iteration:  18201, Training Accuracy: 100.0%
# Optimization Iteration:  18301, Training Accuracy: 100.0%
# Optimization Iteration:  18401, Training Accuracy: 100.0%
# Optimization Iteration:  18501, Training Accuracy: 100.0%
# Optimization Iteration:  18601, Training Accuracy: 100.0%
# Optimization Iteration:  18701, Training Accuracy:  98.4%
# Optimization Iteration:  18801, Training Accuracy: 100.0%
# Optimization Iteration:  18901, Training Accuracy:  98.4%
# Optimization Iteration:  19001, Training Accuracy: 100.0%
# Optimization Iteration:  19101, Training Accuracy:  98.4%
# Optimization Iteration:  19201, Training Accuracy: 100.0%
# Optimization Iteration:  19301, Training Accuracy: 100.0%
# Optimization Iteration:  19401, Training Accuracy: 100.0%
# Optimization Iteration:  19501, Training Accuracy: 100.0%
# Optimization Iteration:  19601, Training Accuracy:  98.4%
# Optimization Iteration:  19701, Training Accuracy: 100.0%
# Optimization Iteration:  19801, Training Accuracy:  98.4%
# Optimization Iteration:  19901, Training Accuracy: 100.0%
# Optimization Iteration:  20001, Training Accuracy: 100.0%
# Optimization Iteration:  20101, Training Accuracy:  98.4%
# Optimization Iteration:  20201, Training Accuracy:  98.4%
# Optimization Iteration:  20301, Training Accuracy: 100.0%
# Optimization Iteration:  20401, Training Accuracy: 100.0%
# Optimization Iteration:  20501, Training Accuracy: 100.0%
# Optimization Iteration:  20601, Training Accuracy: 100.0%
# Optimization Iteration:  20701, Training Accuracy: 100.0%
# Optimization Iteration:  20801, Training Accuracy: 100.0%
# Optimization Iteration:  20901, Training Accuracy: 100.0%
# Optimization Iteration:  21001, Training Accuracy: 100.0%
# Optimization Iteration:  21101, Training Accuracy: 100.0%
# Optimization Iteration:  21201, Training Accuracy: 100.0%
# Optimization Iteration:  21301, Training Accuracy: 100.0%
# Optimization Iteration:  21401, Training Accuracy: 100.0%
# Optimization Iteration:  21501, Training Accuracy: 100.0%
# Optimization Iteration:  21601, Training Accuracy: 100.0%
# Optimization Iteration:  21701, Training Accuracy: 100.0%
# Optimization Iteration:  21801, Training Accuracy: 100.0%
# Optimization Iteration:  21901, Training Accuracy: 100.0%
# Optimization Iteration:  22001, Training Accuracy:  98.4%
# Optimization Iteration:  22101, Training Accuracy: 100.0%
# Optimization Iteration:  22201, Training Accuracy: 100.0%
# Optimization Iteration:  22301, Training Accuracy: 100.0%
# Optimization Iteration:  22401, Training Accuracy: 100.0%
# Optimization Iteration:  22501, Training Accuracy: 100.0%
# Optimization Iteration:  22601, Training Accuracy: 100.0%
# Optimization Iteration:  22701, Training Accuracy: 100.0%
# Optimization Iteration:  22801, Training Accuracy: 100.0%
# Optimization Iteration:  22901, Training Accuracy: 100.0%
# Optimization Iteration:  23001, Training Accuracy: 100.0%
# Optimization Iteration:  23101, Training Accuracy: 100.0%
# Optimization Iteration:  23201, Training Accuracy: 100.0%
# Optimization Iteration:  23301, Training Accuracy: 100.0%
# Optimization Iteration:  23401, Training Accuracy: 100.0%
# Optimization Iteration:  23501, Training Accuracy: 100.0%
# Optimization Iteration:  23601, Training Accuracy:  98.4%
# Optimization Iteration:  23701, Training Accuracy: 100.0%
# Optimization Iteration:  23801, Training Accuracy: 100.0%
# Optimization Iteration:  23901, Training Accuracy:  98.4%
# Optimization Iteration:  24001, Training Accuracy: 100.0%
# Optimization Iteration:  24101, Training Accuracy: 100.0%
# Optimization Iteration:  24201, Training Accuracy: 100.0%
# Optimization Iteration:  24301, Training Accuracy:  96.9%
# Optimization Iteration:  24401, Training Accuracy: 100.0%
# Optimization Iteration:  24501, Training Accuracy: 100.0%
# Optimization Iteration:  24601, Training Accuracy: 100.0%
# Optimization Iteration:  24701, Training Accuracy: 100.0%
# Optimization Iteration:  24801, Training Accuracy: 100.0%
# Optimization Iteration:  24901, Training Accuracy: 100.0%
# Optimization Iteration:  25001, Training Accuracy: 100.0%
# Optimization Iteration:  25101, Training Accuracy: 100.0%
# Optimization Iteration:  25201, Training Accuracy: 100.0%
# Optimization Iteration:  25301, Training Accuracy: 100.0%
# Optimization Iteration:  25401, Training Accuracy: 100.0%
# Optimization Iteration:  25501, Training Accuracy: 100.0%
# Optimization Iteration:  25601, Training Accuracy: 100.0%
# Optimization Iteration:  25701, Training Accuracy: 100.0%
# Optimization Iteration:  25801, Training Accuracy: 100.0%
# Optimization Iteration:  25901, Training Accuracy: 100.0%
# Optimization Iteration:  26001, Training Accuracy: 100.0%
# Optimization Iteration:  26101, Training Accuracy: 100.0%
# Optimization Iteration:  26201, Training Accuracy:  98.4%
# Optimization Iteration:  26301, Training Accuracy: 100.0%
# Optimization Iteration:  26401, Training Accuracy: 100.0%
# Optimization Iteration:  26501, Training Accuracy: 100.0%
# Optimization Iteration:  26601, Training Accuracy: 100.0%
# Optimization Iteration:  26701, Training Accuracy: 100.0%
# Optimization Iteration:  26801, Training Accuracy: 100.0%
# Optimization Iteration:  26901, Training Accuracy: 100.0%
# Optimization Iteration:  27001, Training Accuracy: 100.0%
# Optimization Iteration:  27101, Training Accuracy: 100.0%
# Optimization Iteration:  27201, Training Accuracy: 100.0%
# Optimization Iteration:  27301, Training Accuracy: 100.0%
# Optimization Iteration:  27401, Training Accuracy: 100.0%
# Optimization Iteration:  27501, Training Accuracy: 100.0%
# Optimization Iteration:  27601, Training Accuracy: 100.0%
# Optimization Iteration:  27701, Training Accuracy: 100.0%
# Optimization Iteration:  27801, Training Accuracy: 100.0%
# Optimization Iteration:  27901, Training Accuracy: 100.0%
# Optimization Iteration:  28001, Training Accuracy: 100.0%
# Optimization Iteration:  28101, Training Accuracy: 100.0%
# Optimization Iteration:  28201, Training Accuracy: 100.0%
# Optimization Iteration:  28301, Training Accuracy: 100.0%
# Optimization Iteration:  28401, Training Accuracy: 100.0%
# Optimization Iteration:  28501, Training Accuracy: 100.0%
# Optimization Iteration:  28601, Training Accuracy: 100.0%
# Optimization Iteration:  28701, Training Accuracy:  98.4%
# Optimization Iteration:  28801, Training Accuracy:  98.4%
# Optimization Iteration:  28901, Training Accuracy: 100.0%
# Optimization Iteration:  29001, Training Accuracy:  98.4%
# Optimization Iteration:  29101, Training Accuracy: 100.0%
# Optimization Iteration:  29201, Training Accuracy:  98.4%
# Optimization Iteration:  29301, Training Accuracy: 100.0%
# Optimization Iteration:  29401, Training Accuracy: 100.0%
# Optimization Iteration:  29501, Training Accuracy:  96.9%
# Optimization Iteration:  29601, Training Accuracy: 100.0%
# Optimization Iteration:  29701, Training Accuracy: 100.0%
# Optimization Iteration:  29801, Training Accuracy: 100.0%
# Optimization Iteration:  29901, Training Accuracy: 100.0%
# Optimization Iteration:  30001, Training Accuracy: 100.0%
# Optimization Iteration:  30101, Training Accuracy: 100.0%
# Optimization Iteration:  30201, Training Accuracy: 100.0%
# Optimization Iteration:  30301, Training Accuracy: 100.0%
# Optimization Iteration:  30401, Training Accuracy: 100.0%
# Optimization Iteration:  30501, Training Accuracy: 100.0%
# Optimization Iteration:  30601, Training Accuracy: 100.0%
# Optimization Iteration:  30701, Training Accuracy:  98.4%
# Optimization Iteration:  30801, Training Accuracy: 100.0%
# Optimization Iteration:  30901, Training Accuracy: 100.0%
# Optimization Iteration:  31001, Training Accuracy: 100.0%
# Optimization Iteration:  31101, Training Accuracy: 100.0%
# Optimization Iteration:  31201, Training Accuracy: 100.0%
# Optimization Iteration:  31301, Training Accuracy: 100.0%
# Optimization Iteration:  31401, Training Accuracy: 100.0%
# Optimization Iteration:  31501, Training Accuracy: 100.0%
# Optimization Iteration:  31601, Training Accuracy: 100.0%
# Optimization Iteration:  31701, Training Accuracy: 100.0%
# Optimization Iteration:  31801, Training Accuracy: 100.0%
# Optimization Iteration:  31901, Training Accuracy: 100.0%
# Optimization Iteration:  32001, Training Accuracy: 100.0%
# Optimization Iteration:  32101, Training Accuracy: 100.0%
# Optimization Iteration:  32201, Training Accuracy: 100.0%
# Optimization Iteration:  32301, Training Accuracy: 100.0%
# Optimization Iteration:  32401, Training Accuracy: 100.0%
# Optimization Iteration:  32501, Training Accuracy: 100.0%
# Optimization Iteration:  32601, Training Accuracy: 100.0%
# Optimization Iteration:  32701, Training Accuracy:  98.4%
# Optimization Iteration:  32801, Training Accuracy: 100.0%
# Optimization Iteration:  32901, Training Accuracy: 100.0%
# Optimization Iteration:  33001, Training Accuracy: 100.0%
# Optimization Iteration:  33101, Training Accuracy: 100.0%
# Optimization Iteration:  33201, Training Accuracy: 100.0%
# Optimization Iteration:  33301, Training Accuracy: 100.0%
# Optimization Iteration:  33401, Training Accuracy: 100.0%
# Optimization Iteration:  33501, Training Accuracy: 100.0%
# Optimization Iteration:  33601, Training Accuracy: 100.0%
# Optimization Iteration:  33701, Training Accuracy: 100.0%
# Optimization Iteration:  33801, Training Accuracy: 100.0%
# Optimization Iteration:  33901, Training Accuracy: 100.0%
# Optimization Iteration:  34001, Training Accuracy: 100.0%
# Optimization Iteration:  34101, Training Accuracy: 100.0%
# Optimization Iteration:  34201, Training Accuracy: 100.0%
# Optimization Iteration:  34301, Training Accuracy: 100.0%
# Optimization Iteration:  34401, Training Accuracy: 100.0%
# Optimization Iteration:  34501, Training Accuracy:  98.4%
# Optimization Iteration:  34601, Training Accuracy: 100.0%
# Optimization Iteration:  34701, Training Accuracy: 100.0%
# Optimization Iteration:  34801, Training Accuracy: 100.0%
# Optimization Iteration:  34901, Training Accuracy: 100.0%
# Optimization Iteration:  35001, Training Accuracy: 100.0%
# Optimization Iteration:  35101, Training Accuracy: 100.0%
# Optimization Iteration:  35201, Training Accuracy: 100.0%
# Optimization Iteration:  35301, Training Accuracy: 100.0%
# Optimization Iteration:  35401, Training Accuracy: 100.0%
# Optimization Iteration:  35501, Training Accuracy: 100.0%
# Optimization Iteration:  35601, Training Accuracy: 100.0%
# Optimization Iteration:  35701, Training Accuracy: 100.0%
# Optimization Iteration:  35801, Training Accuracy: 100.0%
# Optimization Iteration:  35901, Training Accuracy: 100.0%
# Optimization Iteration:  36001, Training Accuracy: 100.0%
# Optimization Iteration:  36101, Training Accuracy: 100.0%
# Optimization Iteration:  36201, Training Accuracy: 100.0%
# Optimization Iteration:  36301, Training Accuracy: 100.0%
# Optimization Iteration:  36401, Training Accuracy: 100.0%
# Optimization Iteration:  36501, Training Accuracy: 100.0%
# Optimization Iteration:  36601, Training Accuracy: 100.0%
# Optimization Iteration:  36701, Training Accuracy: 100.0%
# Optimization Iteration:  36801, Training Accuracy: 100.0%
# Optimization Iteration:  36901, Training Accuracy: 100.0%
# Optimization Iteration:  37001, Training Accuracy: 100.0%
# Optimization Iteration:  37101, Training Accuracy: 100.0%
# Optimization Iteration:  37201, Training Accuracy: 100.0%
# Optimization Iteration:  37301, Training Accuracy: 100.0%
# Optimization Iteration:  37401, Training Accuracy: 100.0%
# Optimization Iteration:  37501, Training Accuracy: 100.0%
# Optimization Iteration:  37601, Training Accuracy: 100.0%
# Optimization Iteration:  37701, Training Accuracy: 100.0%
# Optimization Iteration:  37801, Training Accuracy: 100.0%
# Optimization Iteration:  37901, Training Accuracy: 100.0%
# Optimization Iteration:  38001, Training Accuracy: 100.0%
# Optimization Iteration:  38101, Training Accuracy: 100.0%
# Optimization Iteration:  38201, Training Accuracy: 100.0%
# Optimization Iteration:  38301, Training Accuracy: 100.0%
# Optimization Iteration:  38401, Training Accuracy: 100.0%
# Optimization Iteration:  38501, Training Accuracy: 100.0%
# Optimization Iteration:  38601, Training Accuracy: 100.0%
# Optimization Iteration:  38701, Training Accuracy: 100.0%
# Optimization Iteration:  38801, Training Accuracy: 100.0%
# Optimization Iteration:  38901, Training Accuracy: 100.0%
# Optimization Iteration:  39001, Training Accuracy: 100.0%
# Optimization Iteration:  39101, Training Accuracy: 100.0%
# Optimization Iteration:  39201, Training Accuracy: 100.0%
# Optimization Iteration:  39301, Training Accuracy: 100.0%
# Optimization Iteration:  39401, Training Accuracy: 100.0%
# Optimization Iteration:  39501, Training Accuracy: 100.0%
# Optimization Iteration:  39601, Training Accuracy: 100.0%
# Optimization Iteration:  39701, Training Accuracy: 100.0%
# Optimization Iteration:  39801, Training Accuracy: 100.0%
# Optimization Iteration:  39901, Training Accuracy: 100.0%
# Optimization Iteration:  40001, Training Accuracy: 100.0%
# Optimization Iteration:  40101, Training Accuracy: 100.0%
# Optimization Iteration:  40201, Training Accuracy: 100.0%
# Optimization Iteration:  40301, Training Accuracy: 100.0%
# Optimization Iteration:  40401, Training Accuracy: 100.0%
# Optimization Iteration:  40501, Training Accuracy: 100.0%
# Optimization Iteration:  40601, Training Accuracy: 100.0%
# Optimization Iteration:  40701, Training Accuracy: 100.0%
# Optimization Iteration:  40801, Training Accuracy: 100.0%
# Optimization Iteration:  40901, Training Accuracy: 100.0%
# Optimization Iteration:  41001, Training Accuracy: 100.0%
# Optimization Iteration:  41101, Training Accuracy: 100.0%
# Optimization Iteration:  41201, Training Accuracy:  98.4%
# Optimization Iteration:  41301, Training Accuracy: 100.0%
# Optimization Iteration:  41401, Training Accuracy: 100.0%
# Optimization Iteration:  41501, Training Accuracy: 100.0%
# Optimization Iteration:  41601, Training Accuracy: 100.0%
# Optimization Iteration:  41701, Training Accuracy: 100.0%
# Optimization Iteration:  41801, Training Accuracy: 100.0%
# Optimization Iteration:  41901, Training Accuracy: 100.0%
# Optimization Iteration:  42001, Training Accuracy: 100.0%
# Optimization Iteration:  42101, Training Accuracy: 100.0%
# Optimization Iteration:  42201, Training Accuracy: 100.0%
# Optimization Iteration:  42301, Training Accuracy: 100.0%
# Optimization Iteration:  42401, Training Accuracy: 100.0%
# Optimization Iteration:  42501, Training Accuracy: 100.0%
# Optimization Iteration:  42601, Training Accuracy: 100.0%
# Optimization Iteration:  42701, Training Accuracy: 100.0%
# Optimization Iteration:  42801, Training Accuracy: 100.0%
# Optimization Iteration:  42901, Training Accuracy: 100.0%
# Optimization Iteration:  43001, Training Accuracy: 100.0%
# Optimization Iteration:  43101, Training Accuracy: 100.0%
# Optimization Iteration:  43201, Training Accuracy:  98.4%
# Optimization Iteration:  43301, Training Accuracy: 100.0%
# Optimization Iteration:  43401, Training Accuracy: 100.0%
# Optimization Iteration:  43501, Training Accuracy: 100.0%
# Optimization Iteration:  43601, Training Accuracy: 100.0%
# Optimization Iteration:  43701, Training Accuracy: 100.0%
# Optimization Iteration:  43801, Training Accuracy: 100.0%
# Optimization Iteration:  43901, Training Accuracy: 100.0%
# Optimization Iteration:  44001, Training Accuracy: 100.0%
# Optimization Iteration:  44101, Training Accuracy: 100.0%
# Optimization Iteration:  44201, Training Accuracy: 100.0%
# Optimization Iteration:  44301, Training Accuracy: 100.0%
# Optimization Iteration:  44401, Training Accuracy: 100.0%
# Optimization Iteration:  44501, Training Accuracy: 100.0%
# Optimization Iteration:  44601, Training Accuracy: 100.0%
# Optimization Iteration:  44701, Training Accuracy: 100.0%
# Optimization Iteration:  44801, Training Accuracy: 100.0%
# Optimization Iteration:  44901, Training Accuracy: 100.0%
# Optimization Iteration:  45001, Training Accuracy: 100.0%
# Optimization Iteration:  45101, Training Accuracy: 100.0%
# Optimization Iteration:  45201, Training Accuracy: 100.0%
# Optimization Iteration:  45301, Training Accuracy:  98.4%
# Optimization Iteration:  45401, Training Accuracy: 100.0%
# Optimization Iteration:  45501, Training Accuracy: 100.0%
# Optimization Iteration:  45601, Training Accuracy: 100.0%
# Optimization Iteration:  45701, Training Accuracy: 100.0%
# Optimization Iteration:  45801, Training Accuracy: 100.0%
# Optimization Iteration:  45901, Training Accuracy: 100.0%
# Optimization Iteration:  46001, Training Accuracy: 100.0%
# Optimization Iteration:  46101, Training Accuracy: 100.0%
# Optimization Iteration:  46201, Training Accuracy: 100.0%
# Optimization Iteration:  46301, Training Accuracy: 100.0%
# Optimization Iteration:  46401, Training Accuracy: 100.0%
# Optimization Iteration:  46501, Training Accuracy: 100.0%
# Optimization Iteration:  46601, Training Accuracy: 100.0%
# Optimization Iteration:  46701, Training Accuracy: 100.0%
# Optimization Iteration:  46801, Training Accuracy: 100.0%
# Optimization Iteration:  46901, Training Accuracy: 100.0%
# Optimization Iteration:  47001, Training Accuracy: 100.0%
# Optimization Iteration:  47101, Training Accuracy: 100.0%
# Optimization Iteration:  47201, Training Accuracy: 100.0%
# Optimization Iteration:  47301, Training Accuracy: 100.0%
# Optimization Iteration:  47401, Training Accuracy: 100.0%
# Optimization Iteration:  47501, Training Accuracy: 100.0%
# Optimization Iteration:  47601, Training Accuracy: 100.0%
# Optimization Iteration:  47701, Training Accuracy: 100.0%
# Optimization Iteration:  47801, Training Accuracy: 100.0%
# Optimization Iteration:  47901, Training Accuracy: 100.0%
# Optimization Iteration:  48001, Training Accuracy: 100.0%
# Optimization Iteration:  48101, Training Accuracy: 100.0%
# Optimization Iteration:  48201, Training Accuracy: 100.0%
# Optimization Iteration:  48301, Training Accuracy: 100.0%
# Optimization Iteration:  48401, Training Accuracy: 100.0%
# Optimization Iteration:  48501, Training Accuracy: 100.0%
# Optimization Iteration:  48601, Training Accuracy: 100.0%
# Optimization Iteration:  48701, Training Accuracy: 100.0%
# Optimization Iteration:  48801, Training Accuracy: 100.0%
# Optimization Iteration:  48901, Training Accuracy: 100.0%
# Optimization Iteration:  49001, Training Accuracy: 100.0%
# Optimization Iteration:  49101, Training Accuracy: 100.0%
# Optimization Iteration:  49201, Training Accuracy: 100.0%
# Optimization Iteration:  49301, Training Accuracy: 100.0%
# Optimization Iteration:  49401, Training Accuracy: 100.0%
# Optimization Iteration:  49501, Training Accuracy: 100.0%
# Optimization Iteration:  49601, Training Accuracy: 100.0%
# Optimization Iteration:  49701, Training Accuracy: 100.0%
# Optimization Iteration:  49801, Training Accuracy: 100.0%
# Optimization Iteration:  49901, Training Accuracy: 100.0%
# Optimization Iteration:  50001, Training Accuracy: 100.0%
# Optimization Iteration:  50101, Training Accuracy: 100.0%
# Optimization Iteration:  50201, Training Accuracy: 100.0%
# Optimization Iteration:  50301, Training Accuracy: 100.0%
# Optimization Iteration:  50401, Training Accuracy: 100.0%
# Optimization Iteration:  50501, Training Accuracy: 100.0%
# Optimization Iteration:  50601, Training Accuracy: 100.0%
# Optimization Iteration:  50701, Training Accuracy: 100.0%
# Optimization Iteration:  50801, Training Accuracy: 100.0%
# Optimization Iteration:  50901, Training Accuracy: 100.0%
# Optimization Iteration:  51001, Training Accuracy: 100.0%
# Optimization Iteration:  51101, Training Accuracy: 100.0%
# Optimization Iteration:  51201, Training Accuracy: 100.0%
# Optimization Iteration:  51301, Training Accuracy: 100.0%
# Optimization Iteration:  51401, Training Accuracy: 100.0%
# Optimization Iteration:  51501, Training Accuracy: 100.0%
# Optimization Iteration:  51601, Training Accuracy: 100.0%
# Optimization Iteration:  51701, Training Accuracy: 100.0%
# Optimization Iteration:  51801, Training Accuracy: 100.0%
# Optimization Iteration:  51901, Training Accuracy: 100.0%
# Optimization Iteration:  52001, Training Accuracy: 100.0%
# Optimization Iteration:  52101, Training Accuracy: 100.0%
# Optimization Iteration:  52201, Training Accuracy: 100.0%
# Optimization Iteration:  52301, Training Accuracy: 100.0%
# Optimization Iteration:  52401, Training Accuracy: 100.0%
# Optimization Iteration:  52501, Training Accuracy: 100.0%
# Optimization Iteration:  52601, Training Accuracy: 100.0%
# Optimization Iteration:  52701, Training Accuracy:  98.4%
# Optimization Iteration:  52801, Training Accuracy: 100.0%
# Optimization Iteration:  52901, Training Accuracy: 100.0%
# Optimization Iteration:  53001, Training Accuracy: 100.0%
# Optimization Iteration:  53101, Training Accuracy: 100.0%
# Optimization Iteration:  53201, Training Accuracy: 100.0%
# Optimization Iteration:  53301, Training Accuracy: 100.0%
# Optimization Iteration:  53401, Training Accuracy: 100.0%
# Optimization Iteration:  53501, Training Accuracy: 100.0%
# Optimization Iteration:  53601, Training Accuracy: 100.0%
# Optimization Iteration:  53701, Training Accuracy: 100.0%
# Optimization Iteration:  53801, Training Accuracy: 100.0%
# Optimization Iteration:  53901, Training Accuracy: 100.0%
# Optimization Iteration:  54001, Training Accuracy: 100.0%
# Optimization Iteration:  54101, Training Accuracy: 100.0%
# Optimization Iteration:  54201, Training Accuracy: 100.0%
# Optimization Iteration:  54301, Training Accuracy: 100.0%
# Optimization Iteration:  54401, Training Accuracy: 100.0%
# Optimization Iteration:  54501, Training Accuracy: 100.0%
# Optimization Iteration:  54601, Training Accuracy: 100.0%
# Optimization Iteration:  54701, Training Accuracy: 100.0%
# Optimization Iteration:  54801, Training Accuracy: 100.0%
# Optimization Iteration:  54901, Training Accuracy: 100.0%
# Optimization Iteration:  55001, Training Accuracy: 100.0%
# Optimization Iteration:  55101, Training Accuracy: 100.0%
# Optimization Iteration:  55201, Training Accuracy: 100.0%
# Optimization Iteration:  55301, Training Accuracy: 100.0%
# Optimization Iteration:  55401, Training Accuracy: 100.0%
# Optimization Iteration:  55501, Training Accuracy: 100.0%
# Optimization Iteration:  55601, Training Accuracy: 100.0%
# Optimization Iteration:  55701, Training Accuracy: 100.0%
# Optimization Iteration:  55801, Training Accuracy: 100.0%
# Optimization Iteration:  55901, Training Accuracy: 100.0%
# Optimization Iteration:  56001, Training Accuracy: 100.0%
# Optimization Iteration:  56101, Training Accuracy: 100.0%
# Optimization Iteration:  56201, Training Accuracy: 100.0%
# Optimization Iteration:  56301, Training Accuracy: 100.0%
# Optimization Iteration:  56401, Training Accuracy: 100.0%
# Optimization Iteration:  56501, Training Accuracy: 100.0%
# Optimization Iteration:  56601, Training Accuracy: 100.0%
# Optimization Iteration:  56701, Training Accuracy: 100.0%
# Optimization Iteration:  56801, Training Accuracy: 100.0%
# Optimization Iteration:  56901, Training Accuracy: 100.0%
# Optimization Iteration:  57001, Training Accuracy: 100.0%
# Optimization Iteration:  57101, Training Accuracy: 100.0%
# Optimization Iteration:  57201, Training Accuracy: 100.0%
# Optimization Iteration:  57301, Training Accuracy: 100.0%
# Optimization Iteration:  57401, Training Accuracy: 100.0%
# Optimization Iteration:  57501, Training Accuracy: 100.0%
# Optimization Iteration:  57601, Training Accuracy: 100.0%
# Optimization Iteration:  57701, Training Accuracy: 100.0%
# Optimization Iteration:  57801, Training Accuracy: 100.0%
# Optimization Iteration:  57901, Training Accuracy: 100.0%
# Optimization Iteration:  58001, Training Accuracy: 100.0%
# Optimization Iteration:  58101, Training Accuracy: 100.0%
# Optimization Iteration:  58201, Training Accuracy: 100.0%
# Optimization Iteration:  58301, Training Accuracy: 100.0%
# Optimization Iteration:  58401, Training Accuracy: 100.0%
# Optimization Iteration:  58501, Training Accuracy: 100.0%
# Optimization Iteration:  58601, Training Accuracy: 100.0%
# Optimization Iteration:  58701, Training Accuracy: 100.0%
# Optimization Iteration:  58801, Training Accuracy: 100.0%
# Optimization Iteration:  58901, Training Accuracy: 100.0%
# Optimization Iteration:  59001, Training Accuracy: 100.0%
# Optimization Iteration:  59101, Training Accuracy: 100.0%
# Optimization Iteration:  59201, Training Accuracy: 100.0%
# Optimization Iteration:  59301, Training Accuracy: 100.0%
# Optimization Iteration:  59401, Training Accuracy: 100.0%
# Optimization Iteration:  59501, Training Accuracy: 100.0%
# Optimization Iteration:  59601, Training Accuracy: 100.0%
# Optimization Iteration:  59701, Training Accuracy: 100.0%
# Optimization Iteration:  59801, Training Accuracy: 100.0%
# Optimization Iteration:  59901, Training Accuracy: 100.0%
# Optimization Iteration:  60001, Training Accuracy: 100.0%
# Optimization Iteration:  60101, Training Accuracy: 100.0%
# Optimization Iteration:  60201, Training Accuracy: 100.0%
# Optimization Iteration:  60301, Training Accuracy: 100.0%
# Optimization Iteration:  60401, Training Accuracy: 100.0%
# Optimization Iteration:  60501, Training Accuracy: 100.0%
# Optimization Iteration:  60601, Training Accuracy: 100.0%
# Optimization Iteration:  60701, Training Accuracy: 100.0%
# Optimization Iteration:  60801, Training Accuracy: 100.0%
# Optimization Iteration:  60901, Training Accuracy: 100.0%
# Optimization Iteration:  61001, Training Accuracy: 100.0%
# Optimization Iteration:  61101, Training Accuracy: 100.0%
# Optimization Iteration:  61201, Training Accuracy: 100.0%
# Optimization Iteration:  61301, Training Accuracy: 100.0%
# Optimization Iteration:  61401, Training Accuracy: 100.0%
# Optimization Iteration:  61501, Training Accuracy: 100.0%
# Optimization Iteration:  61601, Training Accuracy: 100.0%
# Optimization Iteration:  61701, Training Accuracy: 100.0%
# Optimization Iteration:  61801, Training Accuracy: 100.0%
# Optimization Iteration:  61901, Training Accuracy: 100.0%
# Optimization Iteration:  62001, Training Accuracy: 100.0%
# Optimization Iteration:  62101, Training Accuracy: 100.0%
# Optimization Iteration:  62201, Training Accuracy: 100.0%
# Optimization Iteration:  62301, Training Accuracy: 100.0%
# Optimization Iteration:  62401, Training Accuracy: 100.0%
# Optimization Iteration:  62501, Training Accuracy: 100.0%
# Optimization Iteration:  62601, Training Accuracy: 100.0%
# Optimization Iteration:  62701, Training Accuracy: 100.0%
# Optimization Iteration:  62801, Training Accuracy: 100.0%
# Optimization Iteration:  62901, Training Accuracy: 100.0%
# Optimization Iteration:  63001, Training Accuracy: 100.0%
# Optimization Iteration:  63101, Training Accuracy: 100.0%
# Optimization Iteration:  63201, Training Accuracy: 100.0%
# Optimization Iteration:  63301, Training Accuracy: 100.0%
# Optimization Iteration:  63401, Training Accuracy: 100.0%
# Optimization Iteration:  63501, Training Accuracy: 100.0%
# Optimization Iteration:  63601, Training Accuracy: 100.0%
# Optimization Iteration:  63701, Training Accuracy: 100.0%
# Optimization Iteration:  63801, Training Accuracy: 100.0%
# Optimization Iteration:  63901, Training Accuracy: 100.0%
# Optimization Iteration:  64001, Training Accuracy: 100.0%
# Optimization Iteration:  64101, Training Accuracy: 100.0%
# Optimization Iteration:  64201, Training Accuracy: 100.0%
# Optimization Iteration:  64301, Training Accuracy: 100.0%
# Optimization Iteration:  64401, Training Accuracy: 100.0%
# Optimization Iteration:  64501, Training Accuracy: 100.0%
# Optimization Iteration:  64601, Training Accuracy: 100.0%
# Optimization Iteration:  64701, Training Accuracy: 100.0%
# Optimization Iteration:  64801, Training Accuracy: 100.0%
# Optimization Iteration:  64901, Training Accuracy: 100.0%
# Optimization Iteration:  65001, Training Accuracy: 100.0%
# Optimization Iteration:  65101, Training Accuracy: 100.0%
# Optimization Iteration:  65201, Training Accuracy: 100.0%
# Optimization Iteration:  65301, Training Accuracy: 100.0%
# Optimization Iteration:  65401, Training Accuracy: 100.0%
# Optimization Iteration:  65501, Training Accuracy: 100.0%
# Optimization Iteration:  65601, Training Accuracy: 100.0%
# Optimization Iteration:  65701, Training Accuracy: 100.0%
# Optimization Iteration:  65801, Training Accuracy: 100.0%
# Optimization Iteration:  65901, Training Accuracy: 100.0%
# Optimization Iteration:  66001, Training Accuracy: 100.0%
# Optimization Iteration:  66101, Training Accuracy: 100.0%
# Optimization Iteration:  66201, Training Accuracy: 100.0%
# Optimization Iteration:  66301, Training Accuracy: 100.0%
# Optimization Iteration:  66401, Training Accuracy: 100.0%
# Optimization Iteration:  66501, Training Accuracy: 100.0%
# Optimization Iteration:  66601, Training Accuracy: 100.0%
# Optimization Iteration:  66701, Training Accuracy: 100.0%
# Optimization Iteration:  66801, Training Accuracy: 100.0%
# Optimization Iteration:  66901, Training Accuracy: 100.0%
# Optimization Iteration:  67001, Training Accuracy: 100.0%
# Optimization Iteration:  67101, Training Accuracy: 100.0%
# Optimization Iteration:  67201, Training Accuracy: 100.0%
# Optimization Iteration:  67301, Training Accuracy: 100.0%
# Optimization Iteration:  67401, Training Accuracy: 100.0%
# Optimization Iteration:  67501, Training Accuracy: 100.0%
# Optimization Iteration:  67601, Training Accuracy: 100.0%
# Optimization Iteration:  67701, Training Accuracy: 100.0%
# Optimization Iteration:  67801, Training Accuracy: 100.0%
# Optimization Iteration:  67901, Training Accuracy: 100.0%
# Optimization Iteration:  68001, Training Accuracy: 100.0%
# Optimization Iteration:  68101, Training Accuracy: 100.0%
# Optimization Iteration:  68201, Training Accuracy: 100.0%
# Optimization Iteration:  68301, Training Accuracy: 100.0%
# Optimization Iteration:  68401, Training Accuracy: 100.0%
# Optimization Iteration:  68501, Training Accuracy: 100.0%
# Optimization Iteration:  68601, Training Accuracy: 100.0%
# Optimization Iteration:  68701, Training Accuracy: 100.0%
# Optimization Iteration:  68801, Training Accuracy: 100.0%
# Optimization Iteration:  68901, Training Accuracy: 100.0%
# Optimization Iteration:  69001, Training Accuracy: 100.0%
# Optimization Iteration:  69101, Training Accuracy: 100.0%
# Optimization Iteration:  69201, Training Accuracy: 100.0%
# Optimization Iteration:  69301, Training Accuracy: 100.0%
# Optimization Iteration:  69401, Training Accuracy: 100.0%
# Optimization Iteration:  69501, Training Accuracy: 100.0%
# Optimization Iteration:  69601, Training Accuracy: 100.0%
# Optimization Iteration:  69701, Training Accuracy: 100.0%
# Optimization Iteration:  69801, Training Accuracy: 100.0%
# Optimization Iteration:  69901, Training Accuracy: 100.0%
# Optimization Iteration:  70001, Training Accuracy: 100.0%
# Optimization Iteration:  70101, Training Accuracy: 100.0%
# Optimization Iteration:  70201, Training Accuracy: 100.0%
# Optimization Iteration:  70301, Training Accuracy: 100.0%
# Optimization Iteration:  70401, Training Accuracy: 100.0%
# Optimization Iteration:  70501, Training Accuracy: 100.0%
# Optimization Iteration:  70601, Training Accuracy: 100.0%
# Optimization Iteration:  70701, Training Accuracy: 100.0%
# Optimization Iteration:  70801, Training Accuracy: 100.0%
# Optimization Iteration:  70901, Training Accuracy: 100.0%
# Optimization Iteration:  71001, Training Accuracy: 100.0%
# Optimization Iteration:  71101, Training Accuracy: 100.0%
# Optimization Iteration:  71201, Training Accuracy: 100.0%
# Optimization Iteration:  71301, Training Accuracy: 100.0%
# Optimization Iteration:  71401, Training Accuracy: 100.0%
# Optimization Iteration:  71501, Training Accuracy: 100.0%
# Optimization Iteration:  71601, Training Accuracy: 100.0%
# Optimization Iteration:  71701, Training Accuracy: 100.0%
# Optimization Iteration:  71801, Training Accuracy: 100.0%
# Optimization Iteration:  71901, Training Accuracy: 100.0%
# Optimization Iteration:  72001, Training Accuracy: 100.0%
# Optimization Iteration:  72101, Training Accuracy: 100.0%
# Optimization Iteration:  72201, Training Accuracy: 100.0%
# Optimization Iteration:  72301, Training Accuracy: 100.0%
# Optimization Iteration:  72401, Training Accuracy: 100.0%
# Optimization Iteration:  72501, Training Accuracy: 100.0%
# Optimization Iteration:  72601, Training Accuracy: 100.0%
# Optimization Iteration:  72701, Training Accuracy: 100.0%
# Optimization Iteration:  72801, Training Accuracy: 100.0%
# Optimization Iteration:  72901, Training Accuracy: 100.0%
# Optimization Iteration:  73001, Training Accuracy: 100.0%
# Optimization Iteration:  73101, Training Accuracy: 100.0%
# Optimization Iteration:  73201, Training Accuracy: 100.0%
# Optimization Iteration:  73301, Training Accuracy: 100.0%
# Optimization Iteration:  73401, Training Accuracy: 100.0%
# Optimization Iteration:  73501, Training Accuracy: 100.0%
# Optimization Iteration:  73601, Training Accuracy: 100.0%
# Optimization Iteration:  73701, Training Accuracy: 100.0%
# Optimization Iteration:  73801, Training Accuracy: 100.0%
# Optimization Iteration:  73901, Training Accuracy: 100.0%
# Optimization Iteration:  74001, Training Accuracy: 100.0%
# Optimization Iteration:  74101, Training Accuracy: 100.0%
# Optimization Iteration:  74201, Training Accuracy: 100.0%
# Optimization Iteration:  74301, Training Accuracy: 100.0%
# Optimization Iteration:  74401, Training Accuracy: 100.0%
# Optimization Iteration:  74501, Training Accuracy: 100.0%
# Optimization Iteration:  74601, Training Accuracy: 100.0%
# Optimization Iteration:  74701, Training Accuracy: 100.0%
# Optimization Iteration:  74801, Training Accuracy: 100.0%
# Optimization Iteration:  74901, Training Accuracy: 100.0%
# Optimization Iteration:  75001, Training Accuracy: 100.0%
# Optimization Iteration:  75101, Training Accuracy: 100.0%
# Optimization Iteration:  75201, Training Accuracy: 100.0%
# Optimization Iteration:  75301, Training Accuracy: 100.0%
# Optimization Iteration:  75401, Training Accuracy: 100.0%
# Optimization Iteration:  75501, Training Accuracy: 100.0%
# Optimization Iteration:  75601, Training Accuracy: 100.0%
# Optimization Iteration:  75701, Training Accuracy: 100.0%
# Optimization Iteration:  75801, Training Accuracy: 100.0%
# Optimization Iteration:  75901, Training Accuracy: 100.0%
# Optimization Iteration:  76001, Training Accuracy: 100.0%
# Optimization Iteration:  76101, Training Accuracy: 100.0%
# Optimization Iteration:  76201, Training Accuracy: 100.0%
# Optimization Iteration:  76301, Training Accuracy: 100.0%
# Optimization Iteration:  76401, Training Accuracy: 100.0%
# Optimization Iteration:  76501, Training Accuracy: 100.0%
# Optimization Iteration:  76601, Training Accuracy: 100.0%
# Optimization Iteration:  76701, Training Accuracy: 100.0%
# Optimization Iteration:  76801, Training Accuracy: 100.0%
# Optimization Iteration:  76901, Training Accuracy: 100.0%
# Optimization Iteration:  77001, Training Accuracy: 100.0%
# Optimization Iteration:  77101, Training Accuracy: 100.0%
# Optimization Iteration:  77201, Training Accuracy: 100.0%
# Optimization Iteration:  77301, Training Accuracy: 100.0%
# Optimization Iteration:  77401, Training Accuracy: 100.0%
# Optimization Iteration:  77501, Training Accuracy: 100.0%
# Optimization Iteration:  77601, Training Accuracy: 100.0%
# Optimization Iteration:  77701, Training Accuracy: 100.0%
# Optimization Iteration:  77801, Training Accuracy: 100.0%
# Optimization Iteration:  77901, Training Accuracy: 100.0%
# Optimization Iteration:  78001, Training Accuracy: 100.0%
# Optimization Iteration:  78101, Training Accuracy: 100.0%
# Optimization Iteration:  78201, Training Accuracy: 100.0%
# Optimization Iteration:  78301, Training Accuracy: 100.0%
# Optimization Iteration:  78401, Training Accuracy: 100.0%
# Optimization Iteration:  78501, Training Accuracy: 100.0%
# Optimization Iteration:  78601, Training Accuracy: 100.0%
# Optimization Iteration:  78701, Training Accuracy: 100.0%
# Optimization Iteration:  78801, Training Accuracy: 100.0%
# Optimization Iteration:  78901, Training Accuracy: 100.0%
# Optimization Iteration:  79001, Training Accuracy: 100.0%
# Optimization Iteration:  79101, Training Accuracy: 100.0%
# Optimization Iteration:  79201, Training Accuracy: 100.0%
# Optimization Iteration:  79301, Training Accuracy: 100.0%
# Optimization Iteration:  79401, Training Accuracy: 100.0%
# Optimization Iteration:  79501, Training Accuracy: 100.0%
# Optimization Iteration:  79601, Training Accuracy: 100.0%
# Optimization Iteration:  79701, Training Accuracy: 100.0%
# Optimization Iteration:  79801, Training Accuracy: 100.0%
# Optimization Iteration:  79901, Training Accuracy: 100.0%
# Optimization Iteration:  80001, Training Accuracy: 100.0%
# Optimization Iteration:  80101, Training Accuracy: 100.0%
# Optimization Iteration:  80201, Training Accuracy: 100.0%
# Optimization Iteration:  80301, Training Accuracy: 100.0%
# Optimization Iteration:  80401, Training Accuracy: 100.0%
# Optimization Iteration:  80501, Training Accuracy: 100.0%
# Optimization Iteration:  80601, Training Accuracy: 100.0%
# Optimization Iteration:  80701, Training Accuracy: 100.0%
# Optimization Iteration:  80801, Training Accuracy: 100.0%
# Optimization Iteration:  80901, Training Accuracy: 100.0%
# Optimization Iteration:  81001, Training Accuracy: 100.0%
# Optimization Iteration:  81101, Training Accuracy: 100.0%
# Optimization Iteration:  81201, Training Accuracy: 100.0%
# Optimization Iteration:  81301, Training Accuracy: 100.0%
# Optimization Iteration:  81401, Training Accuracy: 100.0%
# Optimization Iteration:  81501, Training Accuracy: 100.0%
# Optimization Iteration:  81601, Training Accuracy: 100.0%
# Optimization Iteration:  81701, Training Accuracy: 100.0%
# Optimization Iteration:  81801, Training Accuracy: 100.0%
# Optimization Iteration:  81901, Training Accuracy: 100.0%
# Optimization Iteration:  82001, Training Accuracy: 100.0%
# Optimization Iteration:  82101, Training Accuracy: 100.0%
# Optimization Iteration:  82201, Training Accuracy: 100.0%
# Optimization Iteration:  82301, Training Accuracy: 100.0%
# Optimization Iteration:  82401, Training Accuracy: 100.0%
# Optimization Iteration:  82501, Training Accuracy: 100.0%
# Optimization Iteration:  82601, Training Accuracy: 100.0%
# Optimization Iteration:  82701, Training Accuracy: 100.0%
# Optimization Iteration:  82801, Training Accuracy: 100.0%
# Optimization Iteration:  82901, Training Accuracy: 100.0%
# Optimization Iteration:  83001, Training Accuracy: 100.0%
# Optimization Iteration:  83101, Training Accuracy: 100.0%
# Optimization Iteration:  83201, Training Accuracy: 100.0%
# Optimization Iteration:  83301, Training Accuracy: 100.0%
# Optimization Iteration:  83401, Training Accuracy: 100.0%
# Optimization Iteration:  83501, Training Accuracy: 100.0%
# Optimization Iteration:  83601, Training Accuracy: 100.0%
# Optimization Iteration:  83701, Training Accuracy: 100.0%
# Optimization Iteration:  83801, Training Accuracy: 100.0%
# Optimization Iteration:  83901, Training Accuracy: 100.0%
# Optimization Iteration:  84001, Training Accuracy: 100.0%
# Optimization Iteration:  84101, Training Accuracy: 100.0%
# Optimization Iteration:  84201, Training Accuracy: 100.0%
# Optimization Iteration:  84301, Training Accuracy: 100.0%
# Optimization Iteration:  84401, Training Accuracy: 100.0%
# Optimization Iteration:  84501, Training Accuracy: 100.0%
# Optimization Iteration:  84601, Training Accuracy: 100.0%
# Optimization Iteration:  84701, Training Accuracy: 100.0%
# Optimization Iteration:  84801, Training Accuracy: 100.0%
# Optimization Iteration:  84901, Training Accuracy: 100.0%
# Optimization Iteration:  85001, Training Accuracy: 100.0%
# Optimization Iteration:  85101, Training Accuracy: 100.0%
# Optimization Iteration:  85201, Training Accuracy: 100.0%
# Optimization Iteration:  85301, Training Accuracy: 100.0%
# Optimization Iteration:  85401, Training Accuracy: 100.0%
# Optimization Iteration:  85501, Training Accuracy: 100.0%
# Optimization Iteration:  85601, Training Accuracy: 100.0%
# Optimization Iteration:  85701, Training Accuracy: 100.0%
# Optimization Iteration:  85801, Training Accuracy: 100.0%
# Optimization Iteration:  85901, Training Accuracy: 100.0%
# Optimization Iteration:  86001, Training Accuracy: 100.0%
# Optimization Iteration:  86101, Training Accuracy: 100.0%
# Optimization Iteration:  86201, Training Accuracy: 100.0%
# Optimization Iteration:  86301, Training Accuracy: 100.0%
# Optimization Iteration:  86401, Training Accuracy: 100.0%
# Optimization Iteration:  86501, Training Accuracy: 100.0%
# Optimization Iteration:  86601, Training Accuracy: 100.0%
# Optimization Iteration:  86701, Training Accuracy: 100.0%
# Optimization Iteration:  86801, Training Accuracy: 100.0%
# Optimization Iteration:  86901, Training Accuracy: 100.0%
# Optimization Iteration:  87001, Training Accuracy: 100.0%
# Optimization Iteration:  87101, Training Accuracy: 100.0%
# Optimization Iteration:  87201, Training Accuracy: 100.0%
# Optimization Iteration:  87301, Training Accuracy: 100.0%
# Optimization Iteration:  87401, Training Accuracy: 100.0%
# Optimization Iteration:  87501, Training Accuracy: 100.0%
# Optimization Iteration:  87601, Training Accuracy: 100.0%
# Optimization Iteration:  87701, Training Accuracy: 100.0%
# Optimization Iteration:  87801, Training Accuracy: 100.0%
# Optimization Iteration:  87901, Training Accuracy: 100.0%
# Optimization Iteration:  88001, Training Accuracy: 100.0%
# Optimization Iteration:  88101, Training Accuracy: 100.0%
# Optimization Iteration:  88201, Training Accuracy: 100.0%
# Optimization Iteration:  88301, Training Accuracy: 100.0%
# Optimization Iteration:  88401, Training Accuracy: 100.0%
# Optimization Iteration:  88501, Training Accuracy: 100.0%
# Optimization Iteration:  88601, Training Accuracy: 100.0%
# Optimization Iteration:  88701, Training Accuracy:  98.4%
# Optimization Iteration:  88801, Training Accuracy: 100.0%
# Optimization Iteration:  88901, Training Accuracy: 100.0%
# Optimization Iteration:  89001, Training Accuracy: 100.0%
# Optimization Iteration:  89101, Training Accuracy: 100.0%
# Optimization Iteration:  89201, Training Accuracy: 100.0%
# Optimization Iteration:  89301, Training Accuracy: 100.0%
# Optimization Iteration:  89401, Training Accuracy: 100.0%
# Optimization Iteration:  89501, Training Accuracy: 100.0%
# Optimization Iteration:  89601, Training Accuracy: 100.0%
# Optimization Iteration:  89701, Training Accuracy: 100.0%
# Optimization Iteration:  89801, Training Accuracy: 100.0%
# Optimization Iteration:  89901, Training Accuracy: 100.0%
# Optimization Iteration:  90001, Training Accuracy: 100.0%
# Optimization Iteration:  90101, Training Accuracy: 100.0%
# Optimization Iteration:  90201, Training Accuracy: 100.0%
# Optimization Iteration:  90301, Training Accuracy: 100.0%
# Optimization Iteration:  90401, Training Accuracy: 100.0%
# Optimization Iteration:  90501, Training Accuracy: 100.0%
# Optimization Iteration:  90601, Training Accuracy: 100.0%
# Optimization Iteration:  90701, Training Accuracy: 100.0%
# Optimization Iteration:  90801, Training Accuracy: 100.0%
# Optimization Iteration:  90901, Training Accuracy: 100.0%
# Optimization Iteration:  91001, Training Accuracy: 100.0%
# Optimization Iteration:  91101, Training Accuracy: 100.0%
# Optimization Iteration:  91201, Training Accuracy: 100.0%
# Optimization Iteration:  91301, Training Accuracy: 100.0%
# Optimization Iteration:  91401, Training Accuracy: 100.0%
# Optimization Iteration:  91501, Training Accuracy: 100.0%
# Optimization Iteration:  91601, Training Accuracy: 100.0%
# Optimization Iteration:  91701, Training Accuracy: 100.0%
# Optimization Iteration:  91801, Training Accuracy: 100.0%
# Optimization Iteration:  91901, Training Accuracy: 100.0%
# Optimization Iteration:  92001, Training Accuracy: 100.0%
# Optimization Iteration:  92101, Training Accuracy: 100.0%
# Optimization Iteration:  92201, Training Accuracy: 100.0%
# Optimization Iteration:  92301, Training Accuracy: 100.0%
# Optimization Iteration:  92401, Training Accuracy: 100.0%
# Optimization Iteration:  92501, Training Accuracy: 100.0%
# Optimization Iteration:  92601, Training Accuracy: 100.0%
# Optimization Iteration:  92701, Training Accuracy: 100.0%
# Optimization Iteration:  92801, Training Accuracy: 100.0%
# Optimization Iteration:  92901, Training Accuracy: 100.0%
# Optimization Iteration:  93001, Training Accuracy: 100.0%
# Optimization Iteration:  93101, Training Accuracy: 100.0%
# Optimization Iteration:  93201, Training Accuracy: 100.0%
# Optimization Iteration:  93301, Training Accuracy: 100.0%
# Optimization Iteration:  93401, Training Accuracy: 100.0%
# Optimization Iteration:  93501, Training Accuracy: 100.0%
# Optimization Iteration:  93601, Training Accuracy: 100.0%
# Optimization Iteration:  93701, Training Accuracy: 100.0%
# Optimization Iteration:  93801, Training Accuracy: 100.0%
# Optimization Iteration:  93901, Training Accuracy: 100.0%
# Optimization Iteration:  94001, Training Accuracy: 100.0%
# Optimization Iteration:  94101, Training Accuracy: 100.0%
# Optimization Iteration:  94201, Training Accuracy: 100.0%
# Optimization Iteration:  94301, Training Accuracy: 100.0%
# Optimization Iteration:  94401, Training Accuracy: 100.0%
# Optimization Iteration:  94501, Training Accuracy: 100.0%
# Optimization Iteration:  94601, Training Accuracy: 100.0%
# Optimization Iteration:  94701, Training Accuracy: 100.0%
# Optimization Iteration:  94801, Training Accuracy: 100.0%
# Optimization Iteration:  94901, Training Accuracy: 100.0%
# Optimization Iteration:  95001, Training Accuracy: 100.0%
# Optimization Iteration:  95101, Training Accuracy: 100.0%
# Optimization Iteration:  95201, Training Accuracy: 100.0%
# Optimization Iteration:  95301, Training Accuracy: 100.0%
# Optimization Iteration:  95401, Training Accuracy: 100.0%
# Optimization Iteration:  95501, Training Accuracy: 100.0%
# Optimization Iteration:  95601, Training Accuracy: 100.0%
# Optimization Iteration:  95701, Training Accuracy: 100.0%
# Optimization Iteration:  95801, Training Accuracy: 100.0%
# Optimization Iteration:  95901, Training Accuracy: 100.0%
# Optimization Iteration:  96001, Training Accuracy: 100.0%
# Optimization Iteration:  96101, Training Accuracy: 100.0%
# Optimization Iteration:  96201, Training Accuracy: 100.0%
# Optimization Iteration:  96301, Training Accuracy: 100.0%
# Optimization Iteration:  96401, Training Accuracy: 100.0%
# Optimization Iteration:  96501, Training Accuracy: 100.0%
# Optimization Iteration:  96601, Training Accuracy: 100.0%
# Optimization Iteration:  96701, Training Accuracy: 100.0%
# Optimization Iteration:  96801, Training Accuracy: 100.0%
# Optimization Iteration:  96901, Training Accuracy: 100.0%
# Optimization Iteration:  97001, Training Accuracy: 100.0%
# Optimization Iteration:  97101, Training Accuracy: 100.0%
# Optimization Iteration:  97201, Training Accuracy: 100.0%
# Optimization Iteration:  97301, Training Accuracy: 100.0%
# Optimization Iteration:  97401, Training Accuracy: 100.0%
# Optimization Iteration:  97501, Training Accuracy: 100.0%
# Optimization Iteration:  97601, Training Accuracy: 100.0%
# Optimization Iteration:  97701, Training Accuracy: 100.0%
# Optimization Iteration:  97801, Training Accuracy: 100.0%
# Optimization Iteration:  97901, Training Accuracy: 100.0%
# Optimization Iteration:  98001, Training Accuracy: 100.0%
# Optimization Iteration:  98101, Training Accuracy: 100.0%
# Optimization Iteration:  98201, Training Accuracy: 100.0%
# Optimization Iteration:  98301, Training Accuracy: 100.0%
# Optimization Iteration:  98401, Training Accuracy: 100.0%
# Optimization Iteration:  98501, Training Accuracy: 100.0%
# Optimization Iteration:  98601, Training Accuracy: 100.0%
# Optimization Iteration:  98701, Training Accuracy: 100.0%
# Optimization Iteration:  98801, Training Accuracy:  98.4%
# Optimization Iteration:  98901, Training Accuracy: 100.0%
# Optimization Iteration:  99001, Training Accuracy: 100.0%
# Optimization Iteration:  99101, Training Accuracy: 100.0%
# Optimization Iteration:  99201, Training Accuracy: 100.0%
# Optimization Iteration:  99301, Training Accuracy: 100.0%
# Optimization Iteration:  99401, Training Accuracy: 100.0%
# Optimization Iteration:  99501, Training Accuracy: 100.0%
# Optimization Iteration:  99601, Training Accuracy: 100.0%
# Optimization Iteration:  99701, Training Accuracy: 100.0%
# Optimization Iteration:  99801, Training Accuracy: 100.0%
# Optimization Iteration:  99901, Training Accuracy: 100.0%
# Optimization Iteration: 100001, Training Accuracy: 100.0%
# Optimization Iteration: 100101, Training Accuracy: 100.0%
# Optimization Iteration: 100201, Training Accuracy: 100.0%
# Optimization Iteration: 100301, Training Accuracy: 100.0%
# Optimization Iteration: 100401, Training Accuracy: 100.0%
# Optimization Iteration: 100501, Training Accuracy: 100.0%
# Optimization Iteration: 100601, Training Accuracy: 100.0%
# Optimization Iteration: 100701, Training Accuracy: 100.0%
# Optimization Iteration: 100801, Training Accuracy: 100.0%
# Optimization Iteration: 100901, Training Accuracy: 100.0%
# Time usage: 0:08:39

# %%
print_test_accuracy()
# Out:
# Accuracy on Test-Set: 99.1% (9910 / 10000)
